# %%
import pandas as pd

df = pd.read_csv('laptop_price.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB  \
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  \
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.describe(include=['object'])
# Out:
#        Company Product  TypeName   ScreenResolution
# count     1303    1303      1303               1303  \
# unique      19     618         6                 40
# top       Dell  XPS 13  Notebook  Full HD 1920x1080
# freq       297      30       727                507
#
#                                Cpu   Ram     Memory                    Gpu
# count                         1303  1303       1303                   1303  \
# unique                         118     9         39                    110
# top     Intel Core i5 7200U 2.5GHz   8GB  256GB SSD  Intel HD Graphics 620
# freq                           190   619        412                    281
#
#              OpSys Weight
# count         1303   1303
# unique           9    179
# top     Windows 10  2.2kg
# freq          1072    121

# %% [markdown]
# Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU

# %%
# def spl_cpu(my_str: str):
#     return my_str.split()[0]

df['Cpu_Company'] = df['Cpu'].apply(lambda my_str: my_str.split()[0])
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB  \
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  \
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company
# 0      1339.69       Intel
# 1       898.94       Intel
# 2       575.00       Intel
# 3      2537.45       Intel
# 4      1803.60       Intel

# %% [markdown]
# Создать новый признак Memory_Amount,
# который будет содержать только количество Gb памяти без указания типа носителя

# %%
def parse_mem(my_str: str):
    my_str = my_str.split()
    res = 0
    for i in my_str:
        if i.endswith('GB') and i[:-2].isdigit():
            res += int(i[:-2])
        elif i.endswith('TB') and i[:-2].isdigit():
            res += int(i[:-2]) * 1024
    return res
        

# list_mem = ['128GB SSD + 1TB HDD', '64GB Flash Storage', '256GB SSD']
# print(f'{parse_mem(list_mem[2])}')

df['Memory_Amount'] = df['Memory'].apply(parse_mem)
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  \
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB  \
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg  \
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company  Memory_Amount
# 0      1339.69       Intel            128
# 1       898.94       Intel            128
# 2       575.00       Intel            256
# 3      2537.45       Intel            512
# 4      1803.60       Intel            256

# %% [markdown]
# Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD/SDD/др.)

# %%
def mem_type(my_str: str):
    res = []
    if 'HDD' in my_str:
        res.append('HDD')
    if 'SSD' in my_str:
        res.append('SSD')
    if not res:
        return 'other'
    return '/'.join(res)

# list_mem = ['128GB SSD + 1TB HDD', '64GB Flash Storage', '256GB SSD']
# print(f'{mem_type(list_mem[2])}')
df['Memory_Type'] = df['Memory'].apply(mem_type)
df.sample(15)
# Out:
#       laptop_ID  Company              Product            TypeName  Inches
# 957         971       HP         ProBook x360  2 in 1 Convertible    11.6  \
# 244         249   Lenovo       Yoga 910-13IKB  2 in 1 Convertible    13.9
# 430         437  Samsung         Chromebook 3             Netbook    11.6
# 579         586     Dell        Inspiron 3567            Notebook    15.6
# 315         320     Dell        Inspiron 5570            Notebook    15.6
# 1184       1202       HP  Pavilion 15-BC000nv            Notebook    15.6
# 1064       1079      MSI           GS63VR 6RF              Gaming    15.6
# 1164       1182       HP               250 G4            Notebook    15.6
# 1252       1270   Lenovo    IdeaPad 310-15ISK            Notebook    15.6
# 710         718   Lenovo   Legion Y520-15IKBN              Gaming    15.6
# 1038       1052     Dell       Latitude E5570            Notebook    15.6
# 1026       1040       HP          ProBook 650            Notebook    14.0
# 521         528       HP         Spectre X360           Ultrabook    13.3
# 623         630  Fujitsu        LifeBook A557            Notebook    15.6
# 964         978       HP          ProBook 450            Notebook    15.6
#
#                                ScreenResolution
# 957                        Touchscreen 1366x768  \
# 244   IPS Panel Full HD / Touchscreen 1920x1080
# 430                                    1366x768
# 579                           Full HD 1920x1080
# 315                           Full HD 1920x1080
# 1184                IPS Panel Full HD 1920x1080
# 1064                          Full HD 1920x1080
# 1164                                   1366x768
# 1252                          Full HD 1920x1080
# 710                 IPS Panel Full HD 1920x1080
# 1038                          Full HD 1920x1080
# 1026                                   1366x768
# 521                 IPS Panel Full HD 1920x1080
# 623                                    1366x768
# 964                                    1366x768
#
#                                        Cpu   Ram                Memory
# 957   Intel Pentium Quad Core N4200 1.1GHz   4GB             256GB SSD  \
# 244             Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 430   Intel Celeron Dual Core N3060 1.6GHz   4GB    16GB Flash Storage
# 579             Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 315             Intel Core i5 8250U 1.6GHz   8GB  128GB SSD +  1TB HDD
# 1184           Intel Core i7 6700HQ 2.6GHz   6GB               1TB HDD
# 1064           Intel Core i7 6700HQ 2.6GHz  16GB  256GB SSD +  1TB HDD
# 1164            Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 1252            Intel Core i3 6100U 2.3GHz   6GB             128GB SSD
# 710            Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 1038            Intel Core i5 6300U 2.4GHz   8GB             256GB SSD
# 1026            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 521             Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 623             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 964            Intel Core i5 7200U 2.50GHz   8GB               1TB HDD
#
#                              Gpu       OpSys  Weight  Price_euros Cpu_Company
# 957        Intel HD Graphics 505  Windows 10  1.45kg       775.00       Intel  \
# 244        Intel HD Graphics 620  Windows 10  1.38kg      1079.00       Intel
# 430        Intel HD Graphics 400   Chrome OS  1.15kg       269.00       Intel
# 579           AMD Radeon R5 M430       Linux   2.2kg       749.01       Intel
# 315               AMD Radeon 530  Windows 10  2.33kg       844.00       Intel
# 1184     Nvidia GeForce GTX 960M  Windows 10  2.18kg       799.00       Intel
# 1064     Nvidia GeForce GTX 1060  Windows 10   1.8kg      1929.00       Intel
# 1164       Intel HD Graphics 520       No OS   2.1kg       476.99       Intel
# 1252        Nvidia GeForce 920MX  Windows 10   2.4kg       569.00       Intel
# 710   Nvidia GeForce GTX 1050 Ti  Windows 10   2.5kg      1249.00       Intel
# 1038       Intel HD Graphics 520   Windows 7  2.09kg      1062.95       Intel
# 1026       Intel HD Graphics 620  Windows 10  2.31kg      1189.00       Intel
# 521        Intel HD Graphics 620  Windows 10  1.32kg      1399.00       Intel
# 623        Intel HD Graphics 620  Windows 10   2.2kg       799.00       Intel
# 964         Nvidia GeForce 930MX  Windows 10  2.04kg       846.50       Intel
#
#       Memory_Amount Memory_Type
# 957             256         SSD
# 244             256         SSD
# 430              16       other
# 579             256         SSD
# 315            1152     HDD/SSD
# 1184           1024         HDD
# 1064           1280     HDD/SSD
# 1164            500         HDD
# 1252            128         SSD
# 710            1152     HDD/SSD
# 1038            256         SSD
# 1026            500         HDD
# 521             256         SSD
# 623             256         SSD
# 964            1024         HDD

# %%
df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)
df.sample(15)
# Out:
#       laptop_ID Company             Product  TypeName  Inches
# 557         564  Lenovo   IdeaPad 320-17IKB  Notebook    17.3  \
# 1199       1217     MSI          GS73VR 7RF    Gaming    17.3
# 35           36  Lenovo  IdeaPad 120S-14IAP  Notebook    14.0
# 305         310  Lenovo   IdeaPad 320-15IAP  Notebook    15.6
# 120         123    Acer              Spin 3  Notebook    15.6
# 509         516  Lenovo  Legion Y520-15IKBN    Gaming    15.6
# 817         826      HP       Chromebook 11   Netbook    11.6
# 1153       1171    Dell       Inspiron 7567    Gaming    15.6
# 202         206    Acer      Aspire E5-576G  Notebook    15.6
# 526         533  Lenovo   IdeaPad 320-15IKB  Notebook    15.6
# 785         794     MSI          GS43VR 7RE    Gaming    14.0
# 1239       1257  Lenovo         ThinkPad 13  Notebook    13.3
# 205         209  Lenovo  Legion Y520-15IKBN    Gaming    15.6
# 276         281    Dell       Inspiron 5770  Notebook    17.3
# 814         823    Dell         Vostro 3568  Notebook    15.6
#
#                                        Cpu   Ram                        Gpu
# 557             Intel Core i7 7500U 2.7GHz   6GB       Nvidia GeForce 940MX  \
# 1199           Intel Core i7 7700HQ 2.8GHz  16GB    Nvidia GeForce GTX 1060
# 35    Intel Celeron Dual Core N3350 1.1GHz   4GB      Intel HD Graphics 500
# 305   Intel Pentium Quad Core N4200 1.1GHz   4GB      Intel HD Graphics 505
# 120             Intel Core i3 7100U 2.4GHz   6GB      Intel HD Graphics 620
# 509            Intel Core i7 7700HQ 2.8GHz   8GB    Nvidia GeForce GTX 1060
# 817   Intel Celeron Dual Core N3060 1.6GHz   4GB      Intel HD Graphics 400
# 1153           Intel Core i7 7700HQ 2.8GHz   8GB  Nvidia GeForce GTX 1050Ti
# 202             Intel Core i7 7500U 2.7GHz   8GB       Nvidia GeForce 940MX
# 526             Intel Core i7 7500U 2.7GHz   4GB       Nvidia GeForce 920MX
# 785            Intel Core i7 7700HQ 2.8GHz  16GB    Nvidia GeForce GTX 1060
# 1239            Intel Core i7 7500U 2.7GHz  16GB      Intel HD Graphics 620
# 205            Intel Core i7 7700HQ 2.8GHz  16GB    Nvidia GeForce GTX 1060
# 276             Intel Core i7 8550U 1.8GHz   8GB             AMD Radeon 530
# 814             Intel Core i5 7200U 2.5GHz   8GB         AMD Radeon R5 M420
#
#            OpSys  Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type
# 557   Windows 10   2.8kg       949.00       Intel           1152     HDD/SSD
# 1199  Windows 10  2.43kg      2048.90       Intel           1280     HDD/SSD
# 35    Windows 10  1.44kg       249.00       Intel             64       other
# 305        No OS   2.2kg       359.99       Intel           1024         HDD
# 120   Windows 10   2.1kg       479.00       Intel           1024         HDD
# 509        No OS   2.4kg      1149.00       Intel           1280     HDD/SSD
# 817    Chrome OS  1.23kg       385.00       Intel             16       other
# 1153  Windows 10  2.62kg      1199.00       Intel           1024         HDD
# 202   Windows 10  2.23kg       742.00       Intel           1024         HDD
# 526   Windows 10   2.2kg       799.00       Intel           1024         HDD
# 785   Windows 10   1.6kg      1891.00       Intel           1280     HDD/SSD
# 1239  Windows 10   1.4kg      1499.00       Intel            512         SSD
# 205        No OS   2.4kg      1398.00       Intel            512         SSD
# 276        Linux   2.8kg      1099.00       Intel           1152     HDD/SSD
# 814   Windows 10  2.18kg       789.81       Intel            256         SSD

# %% [markdown]
# 2.1 Создайте признак SSD, который изначально равен
#
# 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD

# %%
# df['SSD'] = 0
df['SSD'] = df['Memory_Type'].apply(lambda my_str: 1 if 'SSD' in my_str else 0) 
# df['SSD'] = 0
# df.loc['SSD' in df['Memory_Type'], 'SSD'] = 1
df.sample(5)
# Out:
#      laptop_ID Company            Product   TypeName  Inches
# 81          83   Apple        MacBook 12"  Ultrabook    12.0  \
# 466        473    Acer           Aspire 5   Notebook    15.6
# 838        847  Lenovo  N42-20 Chromebook   Notebook    14.0
# 979        993    Asus   Rog GL753VE-DS74     Gaming    17.3
# 522        529    Dell      Latitude 5480   Notebook    14.0
#
#                                       Cpu   Ram                         Gpu
# 81                   Intel Core i5 1.3GHz   8GB       Intel HD Graphics 615  \
# 466              Intel Core i3 6006U 2GHz   4GB    Nvidia GeForce GTX 940MX
# 838  Intel Celeron Quad Core N3160 1.6GHz   4GB       Intel HD Graphics 400
# 979           Intel Core i7 7700HQ 2.8GHz  16GB  Nvidia GeForce GTX 1050 Ti
# 522            Intel Core i5 7300U 2.6GHz   8GB       Intel HD Graphics 620
#
#           OpSys  Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type
# 81        macOS  0.92kg      1510.00       Intel            512         SSD  \
# 466  Windows 10   2.2kg       469.00       Intel            500         HDD
# 838   Chrome OS   1.5kg       325.00       Intel             16       other
# 979  Windows 10  2.99kg      1749.00       Intel           1280     HDD/SSD
# 522  Windows 10  1.64kg      1279.73       Intel            256         SSD
#
#      SSD
# 81     1
# 466    0
# 838    0
# 979    1
# 522    1

# %% [markdown]
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
df['Weight'] = df['Weight'].str.replace('kg', '')
df['Weight'].astype('float')
df.sample(10)
# Out:
#       laptop_ID  Company                             Product
# 170         174   Huawei                          MateBook X  \
# 88           90     Asus  FX503VM-E4007T (i7-7700HQ/16GB/1TB
# 264         269     Dell                       Inspiron 3567
# 1266       1284       HP                 Pavilion 15-AW003nv
# 142         145   Lenovo                  Legion Y520-15IKBN
# 769         778     Acer                      Aspire A315-31
# 444         451       HP                     Omen 15-AX205na
# 872         883  Toshiba                     Tecra A50-D-11D
# 991        1005       HP        15-bs005nv (i3-6006U/4GB/1TB
# 1224       1242     Dell                       Inspiron 5578
#
#                 TypeName  Inches                                   Cpu   Ram
# 170            Ultrabook    13.0            Intel Core i5 7200U 2.5GHz   8GB  \
# 88                Gaming    15.6           Intel Core i7 7700HQ 2.8GHz  16GB
# 264             Notebook    15.6            Intel Core i5 7200U 2.5GHz   8GB
# 1266            Notebook    15.6             AMD A9-Series 9410 2.9GHz   6GB
# 142               Gaming    15.6           Intel Core i7 7700HQ 2.8GHz   8GB
# 769             Notebook    15.6  Intel Pentium Quad Core N4200 1.1GHz   4GB
# 444               Gaming    15.6           Intel Core i7 7700HQ 2.8GHz   8GB
# 872             Notebook    15.6            Intel Core i7 7500U 2.7GHz   8GB
# 991             Notebook    15.6              Intel Core i3 6006U 2GHz   4GB
# 1224  2 in 1 Convertible    15.0            Intel Core i3 7100U 2.4GHz   4GB
#
#                            Gpu       OpSys Weight  Price_euros Cpu_Company
# 170      Intel HD Graphics 620  Windows 10   1.05      1349.00       Intel  \
# 88     Nvidia GeForce GTX 1060  Windows 10    2.2      1449.00       Intel
# 264         AMD Radeon R5 M430  Windows 10   2.24       565.00       Intel
# 1266        AMD Radeon R7 M440  Windows 10   2.04       549.99         AMD
# 142   Nvidia GeForce GTX 1050M       No OS    2.4       869.00       Intel
# 769      Intel HD Graphics 505       Linux    2.1       298.00       Intel
# 444    Nvidia GeForce GTX 1050  Windows 10    2.2      1099.00       Intel
# 872      Intel HD Graphics 620  Windows 10    2.0      1388.00       Intel
# 991             AMD Radeon 520  Windows 10    2.1       499.00       Intel
# 1224     Intel HD Graphics 620  Windows 10   2.08       509.00       Intel
#
#       Memory_Amount Memory_Type  SSD
# 170             256         SSD    1
# 88             1152     HDD/SSD    1
# 264            1024         HDD    0
# 1266              0       other    0
# 142             256         SSD    1
# 769            1024         HDD    0
# 444            1152     HDD/SSD    1
# 872             256         SSD    1
# 991            1152     HDD/SSD    1
# 1224            500         HDD    0

# %% [markdown]
# Создайте датафрейм с клиентами:
#
# laptop_id - это индексы датафрейма с ноутбуками
#
# 3.1 Присоедините к таблице clients данные по ноутбукам через метод join
#
# 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
clients.head()
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
clients_1 = clients.set_index('laptop_id')
laptop_1 = df.set_index('laptop_ID')

# %%
clients_1.join(laptop_1, how='inner')
# Out:
#      client_id Company            Product  TypeName  Inches
# 506         45  Lenovo      ThinkPad L570  Notebook    15.6  \
# 710         67  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 120         33    Dell      Inspiron 7570  Notebook    15.6
#
#                              Cpu  Ram                    Gpu       OpSys
# 506   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  Windows 10  \
# 710  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7  Windows 10
# 120   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX  Windows 10
#
#     Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 506    2.3       911.00       Intel            256         SSD    1
# 710    2.2       429.00         AMD           1024         HDD    0
# 120   2.16      1130.33       Intel           1280     HDD/SSD    1

# %%
clients.merge(df, left_on='laptop_id', right_on='laptop_ID')
# Out:
#    client_id  laptop_id  laptop_ID Company            Product  TypeName
# 0         45        506        506  Lenovo      ThinkPad L570  Notebook  \
# 1         67        710        710  Lenovo  IdeaPad 320-15ABR  Notebook
# 2         33        120        120    Dell      Inspiron 7570  Notebook
#
#    Inches                          Cpu  Ram                    Gpu
# 0    15.6   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  \
# 1    15.6  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 2    15.6   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
#
#         OpSys Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 0  Windows 10    2.3       911.00       Intel            256         SSD    1
# 1  Windows 10    2.2       429.00         AMD           1024         HDD    0
# 2  Windows 10   2.16      1130.33       Intel           1280     HDD/SSD    1

# %% [markdown]
# 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
#
# Отсортируйте от меньшей стоимости к большей

# %%
df.groupby('Company').agg({'Price_euros': 'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %% [markdown]
# 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['mean', 'min', 'max']}).sort_values(('Price_euros', 'mean'))
# Out:
#              Price_euros
#                     mean    min     max
# Cpu_Company
# AMD           560.638871  199.0  2199.0
# Samsung       659.000000  659.0   659.0
# Intel        1152.214145  174.0  6099.0

# %% [markdown]
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ

# %%
df.pivot_table(index='Cpu_Company', columns='Ram', aggfunc='count', values='Product')
# Out:
# Ram          12GB   16GB  24GB   2GB  32GB    4GB  64GB   6GB    8GB
# Cpu_Company
# AMD           2.0    3.0   NaN   1.0   NaN   31.0   NaN  13.0   12.0
# Intel        23.0  197.0   3.0  21.0  17.0  343.0   1.0  28.0  607.0
# Samsung       NaN    NaN   NaN   NaN   NaN    1.0   NaN   NaN    NaN

# %% [markdown]
# 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %%
df.pivot_table(index='OpSys', columns='Memory_Amount', aggfunc='mean', values='Price_euros', fill_value=0)
# Out:
# Memory_Amount      0     8       16          32          64           128
# OpSys
# Android          0.0000     0    0.00    0.000000  434.000000     0.000000  \
# Chrome OS        0.0000     0  305.38  412.454545  774.333333  1275.000000
# Linux            0.0000     0    0.00    0.000000    0.000000   490.500000
# Mac OS X         0.0000     0    0.00    0.000000    0.000000  1099.000000
# No OS            0.0000     0    0.00    0.000000    0.000000   362.024000
# Windows 10     755.5575  2249    0.00  270.001471  333.795556   673.385692
# Windows 10 S     0.0000     0    0.00    0.000000  308.995000  1039.000000
# Windows 7      860.0000     0    0.00    0.000000    0.000000  1320.323333
# macOS            0.0000     0    0.00    0.000000    0.000000  1119.315000
#
# Memory_Amount    180   240          256         500   ...     768
# OpSys                                                 ...
# Android           0.0     0     0.000000    0.000000  ...     0.00  \
# Chrome OS         0.0     0  1559.000000    0.000000  ...     0.00
# Linux             0.0     0   795.814000  389.056364  ...     0.00
# Mac OS X          0.0     0  1311.994000    0.000000  ...     0.00
# No OS             0.0     0   754.834615  404.675385  ...     0.00
# Windows 10     1073.5  3100  1218.868329  664.717647  ...  1607.96
# Windows 10 S      0.0     0  1668.950000    0.000000  ...     0.00
# Windows 7      1199.0     0  1846.466800  924.048333  ...     0.00
# macOS             0.0     0  1600.370000    0.000000  ...     0.00
#
# Memory_Amount        1024  1088         1152        1280         1536
# OpSys
# Android           0.00000     0     0.000000     0.00000     0.000000  \
# Chrome OS         0.00000     0     0.000000     0.00000     0.000000
# Linux           581.40129     0   994.000000     0.00000     0.000000
# Mac OS X          0.00000     0     0.000000     0.00000     0.000000
# No OS           540.53960     0   895.666667  1149.00000     0.000000
# Windows 10      886.22663  1993  1285.464494  1865.97375  2500.447143
# Windows 10 S      0.00000     0     0.000000     0.00000     0.000000
# Windows 7      2899.00000     0     0.000000     0.00000     0.000000
# macOS             0.00000     0     0.000000     0.00000     0.000000
#
# Memory_Amount         2048    2176         2304  2560
# OpSys
# Android           0.000000    0.00     0.000000     0
# Chrome OS         0.000000    0.00     0.000000     0
# Linux             0.000000    0.00  1049.000000     0
# Mac OS X          0.000000    0.00     0.000000     0
# No OS           594.000000    0.00     0.000000     0
# Windows 10     1058.201333  977.95  1590.015556  1849
# Windows 10 S      0.000000    0.00     0.000000     0
# Windows 7         0.000000    0.00     0.000000     0
# macOS             0.000000    0.00     0.000000     0
#
# [9 rows x 23 columns]

# %% [markdown]
# 5.1 Ноутбуков каких компаний и с каким процессором больше?

# %%
tmp_df = pd.crosstab(index=df['Company'], columns=df['Cpu_Company'])

# %%
tmp_df.max()
# Out:
# Cpu_Company
# AMD         25
# Intel      297
# Samsung      1
# dtype: int64

# %% [markdown]
# 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
pd.crosstab(index=df['Memory_Amount'], columns=df['Memory_Type']).max()
# Out:
# Memory_Type
# HDD        223
# HDD/SSD     94
# SSD        413
# other       38
# dtype: int64
